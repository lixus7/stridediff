# %% [markdown]
# # Metric Presentation and Visualization
# ## Necessary packages and functions call
#
# - DDPM-TS: Interpretable Diffusion for Time Series Generation
# - Metrics:
#     - discriminative_metrics
#     - predictive_metrics
#     - visualization

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

import sys
sys.path.append(os.path.join(os.path.dirname('__file__'), '../'))

import warnings
warnings.filterwarnings("ignore")

import numpy as np
import tensorflow as tf
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError as e:
        print(e)

from Utils.metric_utils import display_scores
from Utils.discriminative_metric import discriminative_score_metrics
from Utils.predictive_metric import predictive_score_metrics

# %% [markdown]
# ## Data Loading
#
# Load original dataset and preprocess the loaded data.

# %%
iterations = 5
# ori_data = np.load('../toy_exp/samples/sine_ground_truth_24_train.npy')
ori_data = np.load('../OUTPUT/etth/samples/etth_norm_truth_24_train.npy')  # Uncomment the line if dataset other than Sine is used.
fake_data = np.load('../OUTPUT/etth/ddpm_fake_etth_milestone_10.npy')

discriminative_score = []

for i in range(iterations):
    temp_disc, fake_acc, real_acc = discriminative_score_metrics(ori_data[:], fake_data[:ori_data.shape[0]])
    discriminative_score.append(temp_disc)
    print(f'Iter {i}: ', temp_disc, ',', fake_acc, ',', real_acc, '\n')
      
print('etth:')
display_scores(discriminative_score)
print()
# seed 12345  Final Score:  0.0731896551724138 ± 0.005795392020461213
# seed 2024  Final Score:  0.06945402298850574 ± 0.010002021083688875

predictive_score = []
for i in range(iterations):
    temp_pred = predictive_score_metrics(ori_data, fake_data[:ori_data.shape[0]])
    predictive_score.append(temp_pred)
    print(i, ' epoch: ', temp_pred, '\n')
      
print('sine:')
display_scores(predictive_score)
print()
# Out:
# WARNING:tensorflow:From /scratch/duyin/test/banddiff/Experiments/../Utils/discriminative_metric.py:101: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From /mnt/data728/duyin/anaconda3/envs/torch201/lib/python3.9/site-packages/keras/layers/legacy_rnn/rnn_cell_impl.py:579: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /mnt/data728/duyin/anaconda3/envs/torch201/lib/python3.9/site-packages/keras/layers/legacy_rnn/rnn_cell_impl.py:589: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /scratch/duyin/test/banddiff/Experiments/../Utils/discriminative_metric.py:105: all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Please use tf.global_variables instead.
# training: 100%|██████████| 2000/2000 [00:43<00:00, 45.48it/s]
# Iter 0:  0.11321839080459772 , 0.6436781609195402 , 0.5827586206896552
# training: 100%|██████████| 2000/2000 [00:45<00:00, 43.70it/s]
# Iter 1:  0.11422413793103448 , 0.6859195402298851 , 0.542528735632184
# training: 100%|██████████| 2000/2000 [00:48<00:00, 41.00it/s]
# Iter 2:  0.10660919540229885 , 0.6413793103448275 , 0.5718390804597702
# training: 100%|██████████| 2000/2000 [00:45<00:00, 43.66it/s]
# Iter 3:  0.1186781609195402 , 0.6146551724137931 , 0.6227011494252873
# training: 100%|██████████| 2000/2000 [00:47<00:00, 41.93it/s]
# Iter 4:  0.11206896551724133 , 0.578735632183908 , 0.6454022988505748
#
# etth:
# Final Score:  0.11295977011494251 ± 0.005394056086825369
# training: 100%|██████████| 5000/5000 [01:38<00:00, 50.55it/s]
# 0  epoch:  0.12244250422236129
# training: 100%|██████████| 5000/5000 [01:36<00:00, 51.97it/s]
# 1  epoch:  0.11971305031478092
# training: 100%|██████████| 5000/5000 [01:37<00:00, 51.29it/s]
# 2  epoch:  0.12523951586565293
# training: 100%|██████████| 5000/5000 [01:36<00:00, 51.66it/s]
# 3  epoch:  0.12657106056081388
# training: 100%|██████████| 5000/5000 [01:36<00:00, 51.68it/s]
# 4  epoch:  0.12615619364722766
#
# sine:
# Final Score:  0.12402446492216734 ± 0.0035985053478138256

# %%
iterations = 5
# ori_data = np.load('../toy_exp/samples/sine_ground_truth_24_train.npy')
ori_data = np.load('../OUTPUT/stocks/samples/stock_norm_truth_24_train.npy')  # Uncomment the line if dataset other than Sine is used.
fake_data = np.load('../OUTPUT/stocks/ddpm_fake_stocks_milestone_10.npy')

discriminative_score = []

for i in range(iterations):
    temp_disc, fake_acc, real_acc = discriminative_score_metrics(ori_data[:], fake_data[:ori_data.shape[0]])
    discriminative_score.append(temp_disc)
    print(f'Iter {i}: ', temp_disc, ',', fake_acc, ',', real_acc, '\n')
      
print('etth:')
display_scores(discriminative_score)
print()
# seed 12345  Final Score:  0.0731896551724138 ± 0.005795392020461213
# seed 2024  Final Score:  0.06945402298850574 ± 0.010002021083688875

predictive_score = []
for i in range(iterations):
    temp_pred = predictive_score_metrics(ori_data, fake_data[:ori_data.shape[0]])
    predictive_score.append(temp_pred)
    print(i, ' epoch: ', temp_pred, '\n')
      
print('sine:')
display_scores(predictive_score)
print()
# Out:
# WARNING:tensorflow:From /scratch/duyin/test/banddiff/Experiments/../Utils/discriminative_metric.py:101: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From /mnt/data728/duyin/anaconda3/envs/torch201/lib/python3.9/site-packages/keras/layers/legacy_rnn/rnn_cell_impl.py:579: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /mnt/data728/duyin/anaconda3/envs/torch201/lib/python3.9/site-packages/keras/layers/legacy_rnn/rnn_cell_impl.py:589: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /scratch/duyin/test/banddiff/Experiments/../Utils/discriminative_metric.py:105: all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Please use tf.global_variables instead.
# training: 100%|██████████| 2000/2000 [00:42<00:00, 46.94it/s]
# Iter 0:  0.10845839017735337 , 0.5702592087312415 , 0.6466575716234653
# training: 100%|██████████| 2000/2000 [00:41<00:00, 47.84it/s]
# Iter 1:  0.12755798090040926 , 0.5457025920873124 , 0.7094133697135061
# training: 100%|██████████| 2000/2000 [00:42<00:00, 47.44it/s]
# Iter 2:  0.10777626193724421 , 0.49386084583901774 , 0.7216916780354706
# training: 100%|██████████| 2000/2000 [00:41<00:00, 48.44it/s]
# Iter 3:  0.12619372442019094 , 0.5566166439290586 , 0.6957708049113234
# training: 100%|██████████| 2000/2000 [00:43<00:00, 45.84it/s]
# Iter 4:  0.08663028649386084 , 0.5770804911323328 , 0.5961800818553888
#
# etth:
# Final Score:  0.11132332878581172 ± 0.020732707520038553
# training: 100%|██████████| 5000/5000 [01:34<00:00, 52.66it/s]
# 0  epoch:  0.03716102174805763
# training: 100%|██████████| 5000/5000 [01:33<00:00, 53.44it/s]
# 1  epoch:  0.037382422561400105
# training: 100%|██████████| 5000/5000 [01:32<00:00, 54.23it/s]
# 2  epoch:  0.03742559690929726
# training: 100%|██████████| 5000/5000 [01:34<00:00, 52.91it/s]
# 3  epoch:  0.037397000411882056
# training: 100%|██████████| 5000/5000 [01:34<00:00, 52.95it/s]
# 4  epoch:  0.03728225510084033
#
# sine:
# Final Score:  0.03732965934629547 ± 0.00013489151316377462

# %%
iterations = 5
# ori_data = np.load('../toy_exp/samples/sine_ground_truth_24_train.npy')
ori_data = np.load('../OUTPUT/mujoco/samples/mujoco_norm_truth_24_train.npy')  # Uncomment the line if dataset other than Sine is used.
fake_data = np.load('../OUTPUT/mujoco/ddpm_fake_mujoco_milestone_10.npy')

discriminative_score = []

for i in range(iterations):
    temp_disc, fake_acc, real_acc = discriminative_score_metrics(ori_data[:], fake_data[:ori_data.shape[0]])
    discriminative_score.append(temp_disc)
    print(f'Iter {i}: ', temp_disc, ',', fake_acc, ',', real_acc, '\n')
      
print('etth:')
display_scores(discriminative_score)
print()
# seed 12345  Final Score:  0.0731896551724138 ± 0.005795392020461213
# seed 2024  Final Score:  0.06945402298850574 ± 0.010002021083688875

predictive_score = []
for i in range(iterations):
    temp_pred = predictive_score_metrics(ori_data, fake_data[:ori_data.shape[0]])
    predictive_score.append(temp_pred)
    print(i, ' epoch: ', temp_pred, '\n')
      
print('sine:')
display_scores(predictive_score)
print()
# Out:
# training: 100%|██████████| 2000/2000 [00:43<00:00, 45.56it/s]
# Iter 0:  0.03149999999999997 , 0.378 , 0.685
# training: 100%|██████████| 2000/2000 [00:44<00:00, 44.69it/s]
# Iter 1:  0.04600000000000004 , 0.478 , 0.614
# training: 100%|██████████| 2000/2000 [00:42<00:00, 47.12it/s]
# Iter 2:  0.03774999999999995 , 0.307 , 0.7685
# training: 100%|██████████| 2000/2000 [00:44<00:00, 45.14it/s]
# Iter 3:  0.047250000000000014 , 0.5195 , 0.575
# training: 100%|██████████| 2000/2000 [00:43<00:00, 45.66it/s]
# Iter 4:  0.04349999999999998 , 0.5495 , 0.5375
#
# etth:
# Final Score:  0.041199999999999994 ± 0.008116651281888309
# training: 100%|██████████| 5000/5000 [01:40<00:00, 49.83it/s]
# 0  epoch:  0.008134738174084348
# training: 100%|██████████| 5000/5000 [01:39<00:00, 50.34it/s]
# 1  epoch:  0.00998802998104778
# training: 100%|██████████| 5000/5000 [01:41<00:00, 49.21it/s]
# 2  epoch:  0.006707592307986922
# training: 100%|██████████| 5000/5000 [01:42<00:00, 48.95it/s]
# 3  epoch:  0.009527335492483037
# training: 100%|██████████| 5000/5000 [01:41<00:00, 49.31it/s]
# 4  epoch:  0.0071477852350605685
#
# sine:
# Final Score:  0.00830109623813253 ± 0.0017828219918751419

# %%
iterations = 5
# ori_data = np.load('../toy_exp/samples/sine_ground_truth_24_train.npy')
ori_data = np.load('../OUTPUT/energy/samples/energy_norm_truth_24_train.npy')  # Uncomment the line if dataset other than Sine is used.
fake_data = np.load('../OUTPUT/energy/ddpm_fake_energy_milestone_10.npy')

discriminative_score = []

for i in range(iterations):
    temp_disc, fake_acc, real_acc = discriminative_score_metrics(ori_data[:], fake_data[:ori_data.shape[0]])
    discriminative_score.append(temp_disc)
    print(f'Iter {i}: ', temp_disc, ',', fake_acc, ',', real_acc, '\n')
      
print('etth:')
display_scores(discriminative_score)
print()
# seed 12345  Final Score:  0.0731896551724138 ± 0.005795392020461213
# seed 2024  Final Score:  0.06945402298850574 ± 0.010002021083688875

predictive_score = []
for i in range(iterations):
    temp_pred = predictive_score_metrics(ori_data, fake_data[:ori_data.shape[0]])
    predictive_score.append(temp_pred)
    print(i, ' epoch: ', temp_pred, '\n')
      
print('sine:')
display_scores(predictive_score)
print()
# Out:
# training: 100%|██████████| 2000/2000 [00:59<00:00, 33.36it/s]
# Iter 0:  0.13466903373066197 , 0.5772254628455491 , 0.6921126046157748
# training: 100%|██████████| 2000/2000 [00:58<00:00, 34.37it/s]
# Iter 1:  0.12427085975145824 , 0.7476540705046919 , 0.5008876489982247
# training: 100%|██████████| 2000/2000 [01:01<00:00, 32.52it/s]
# Iter 2:  0.11793050976413899 , 0.7182348465635303 , 0.5176261729647477
# training: 100%|██████████| 2000/2000 [01:02<00:00, 32.15it/s]
# Iter 3:  0.13378138473243728 , 0.579507988840984 , 0.6880547806238905
# training: 100%|██████████| 2000/2000 [01:01<00:00, 32.60it/s]
# Iter 4:  0.12997717474004566 , 0.6274410347451179 , 0.6325133147349734
#
# etth:
# Final Score:  0.12812579254374842 ± 0.008714492124215233
# training: 100%|██████████| 5000/5000 [02:25<00:00, 34.42it/s]
# 0  epoch:  0.2506920656980761
# training: 100%|██████████| 5000/5000 [02:24<00:00, 34.62it/s]
# 1  epoch:  0.2508234896327168
# training: 100%|██████████| 5000/5000 [02:25<00:00, 34.32it/s]
# 2  epoch:  0.2512744952684727
# training: 100%|██████████| 5000/5000 [02:24<00:00, 34.55it/s]
# 3  epoch:  0.25088377208239127
# training: 100%|██████████| 5000/5000 [02:24<00:00, 34.59it/s]
# 4  epoch:  0.25083870274822473
#
# sine:
# Final Score:  0.2509025050859763 ± 0.00027297308607467666

# %%
# fmri
iterations = 5
# ori_data = np.load('../toy_exp/samples/sine_ground_truth_24_train.npy')
ori_data = np.load('../OUTPUT/fmri/samples/fmri_norm_truth_24_train.npy')  # Uncomment the line if dataset other than Sine is used.
fake_data = np.load('../OUTPUT/fmri/ddpm_fake_fmri_milestone_10.npy')

discriminative_score = []

for i in range(iterations):
    temp_disc, fake_acc, real_acc = discriminative_score_metrics(ori_data[:], fake_data[:ori_data.shape[0]])
    discriminative_score.append(temp_disc)
    print(f'Iter {i}: ', temp_disc, ',', fake_acc, ',', real_acc, '\n')
      
print('etth:')
display_scores(discriminative_score)
print()
# seed 12345  Final Score:  0.0731896551724138 ± 0.005795392020461213
# seed 2024  Final Score:  0.06945402298850574 ± 0.010002021083688875

predictive_score = []
for i in range(iterations):
    temp_pred = predictive_score_metrics(ori_data, fake_data[:ori_data.shape[0]])
    predictive_score.append(temp_pred)
    print(i, ' epoch: ', temp_pred, '\n')
      
print('sine:')
display_scores(predictive_score)
print()
# Out:
# WARNING:tensorflow:From /scratch/duyin/test/banddiff/Experiments/../Utils/discriminative_metric.py:101: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From /mnt/data728/duyin/anaconda3/envs/torch201/lib/python3.9/site-packages/keras/layers/legacy_rnn/rnn_cell_impl.py:579: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /mnt/data728/duyin/anaconda3/envs/torch201/lib/python3.9/site-packages/keras/layers/legacy_rnn/rnn_cell_impl.py:589: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /scratch/duyin/test/banddiff/Experiments/../Utils/discriminative_metric.py:105: all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Please use tf.global_variables instead.
# training: 100%|██████████| 2000/2000 [01:08<00:00, 29.33it/s]
# Iter 0:  0.16558116232464926 , 0.9754509018036072 , 0.3557114228456914
# training: 100%|██████████| 2000/2000 [01:05<00:00, 30.33it/s]
# Iter 1:  0.24273547094188375 , 0.7845691382765531 , 0.7009018036072144
# training: 100%|██████████| 2000/2000 [01:07<00:00, 29.58it/s]
# Iter 2:  0.2695390781563126 , 0.8231462925851704 , 0.7159318637274549
# training: 100%|██████████| 2000/2000 [01:09<00:00, 28.98it/s]
# Iter 3:  0.30085170340681366 , 0.8196392785571143 , 0.7820641282565131
# training: 100%|██████████| 2000/2000 [01:07<00:00, 29.72it/s]
# Iter 4:  0.2570140280561122 , 0.8476953907815631 , 0.6663326653306614
#
# etth:
# Final Score:  0.2471442885771543 ± 0.0625637452129619
# training: 100%|██████████| 5000/5000 [02:33<00:00, 32.48it/s]
# 0  epoch:  0.09919126499365956
# training: 100%|██████████| 5000/5000 [02:33<00:00, 32.55it/s]
# 1  epoch:  0.0991864519391175
# training: 100%|██████████| 5000/5000 [02:32<00:00, 32.74it/s]
# 2  epoch:  0.09924817356475822
# training: 100%|██████████| 5000/5000 [02:31<00:00, 33.02it/s]
# 3  epoch:  0.09904586381747478
# training: 100%|██████████| 5000/5000 [02:32<00:00, 32.71it/s]
# 4  epoch:  0.09906707816788549
#
# sine:
# Final Score:  0.09914776649657911 ± 0.00010818347088233862
